# %%
import sys
sys.path.append("/Users/shivangagarwal/Documents/python_projects/genai/chart-to-text")

# %%
import pandas as pd
from scripts.text_to_chart import generate_visualization

# %%
df = pd.read_csv("../data/Iris.csv")
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
generate_visualization(df, "plot correlation between SepalLengthCm and SepalWidthCm")
